# %%
#1
a,b,c,d,e=map(int,input("정수 5개 입력:(구분자'')").split())
abs(a)+abs(b)+abs(c)+abs(d)+abs(e)
# Out:
# 정수 5개 입력:(구분자'')35 -20 10 0 55
# 120

# %%
n=0
for i in map(int,input("정수 5개 입력:(구분자'')").split()):
  n+=abs(i)
print(n)
# Out:
# 정수 5개 입력:(구분자'')35 -20 10 0 55
# 120

# %%
#2
print("안녕하세요")
# Out:
# 안녕하세요

# %%
#3
a=100
b=200
print(a,"+",b,"=",a+b,sep='')
print('%d+%d=%d'%(a,b,a+b))
print('{0}+{1}={2}'.format(a,b,a+b))
print(f"{a}+{b}={a+b}")
print(str(a)+'+'+str(b)+'='+str(a+b)) #문자열끼리는 +(연결연산자)로 연결할수 있다.
# Out:
# 100+200=300
# 100+200=300
# 100+200=300
# 100+200=300
# 100+200=300

# %%
#4
a,b=map(int,input().split())
print("+=",a+b,sep='')
print("-=",a-b,sep='')
print("*=",a*b,sep='')
print("/=",a//b,sep='')
print("%=",a%b,sep='')
# Out:
# 2 1
# +=3
# -=1
# *=2
# /=2
# %=0

# %%
#4
#input("두 정수 입력:")[:2] #몇자리를 입력하든 두자리만 받는다
a,b=map(int,input("두 정수 입력:").split())
print(f'+={a+b}')
print(f'-={a-b}')
print(f'*={a*b}')
print(f'/={a//b}')
print(f'%={a%b}')
# Out:
# 두 정수 입력:2 1
# +=3
# -=1
# *=2
# /=2
# %=0

# %%
#5
a=534
b=30
print(a//b)
print(a%b)
# Out:
# 17
# 24

# %%
#5
연필=534
학생=30
print(f'학생당 갖는 연필수 : {연필//학생}\n남아잇는 연필의 수 : {연필%학생}')
# Out:
# 학생당 갖는 연필수 : 17
# 남아잇는 연필의 수 : 24

# %%
#6
n=123 #몫연산 100나누기 사용하면 됨 -> 곱하기 100
n//=100
n*=100
n
# Out:
# 100

# %%
#일의 자리만 남기기
n=123 #자리수 구할땐 몫연산
n%=10 
n
# Out:
# 3

# %%
a=1234
#1의 자리 %
#10의 자리 //10
#100의 자리 //100
#1000의 자리 //1000
n
n=123245612232323
len(str(n))
# Out:
# 15
