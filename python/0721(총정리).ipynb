# %% [markdown]
# <b><h3> 총정리

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.optimizers import SGD, RMSprop,Adam
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.losses import sparse_categorical_crossentropy,categorical_crossentropy,binary_crossentropy
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Flatten,Dropout
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping

# %% [markdown]
# <b><h3>데이터 수집

# %%
(X_data,y_data),(tt_x,tt_y)=keras.datasets.fashion_mnist.load_data()

# %% [markdown]
# <b><h3>데이터 전처리

# %%
X_data=X_data/255.0
tt_x=tt_x/255.0

# %%
t_x,v_x,t_y,v_y=train_test_split(X_data,y_data,random_state=42,test_size=0.2)

# %% [markdown]
# <b><h3>모델생성 및 학습

# %%
model=Sequential()
model.add(Flatten(input_shape=(28,28)))
model.add(Dense(100,activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(10,activation='softmax'))
model.summary()
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics='accuracy')
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_2 (Dense)             (None, 100)               78500
#
#  dropout_1 (Dropout)         (None, 100)               0
#
#  dense_3 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
from gc import callbacks
ck_p=ModelCheckpoint('best_m.h5')
es=EarlyStopping(patience=2,restore_best_weights=True)
hy=model.fit(t_x,t_y,epochs=100,validation_data=(v_x,v_y),callbacks=[ck_p,es])
# Out:
# Epoch 1/100
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2971 - accuracy: 0.8892 - val_loss: 0.3233 - val_accuracy: 0.8838
# Epoch 2/100
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2936 - accuracy: 0.8906 - val_loss: 0.3127 - val_accuracy: 0.8892
# Epoch 3/100
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2895 - accuracy: 0.8907 - val_loss: 0.3132 - val_accuracy: 0.8902
# Epoch 4/100
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2820 - accuracy: 0.8944 - val_loss: 0.3232 - val_accuracy: 0.8848

# %%
es.stopped_epoch
# Out:
# 10

# %% [markdown]
# <b><h3>태스트 및 검증

# %%
model.evaluate(t_x,t_y)
model.evaluate(tt_x,tt_y)
model.evaluate(v_x,v_y)
# Out:
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2593 - accuracy: 0.9062
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3447 - accuracy: 0.8780
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3180 - accuracy: 0.8864
# [0.31800907850265503, 0.8864166736602783]

# %%
m2=load_model
m2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_2 (Dense)             (None, 100)               78500
#
#  dropout_1 (Dropout)         (None, 100)               0
#
#  dense_3 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
m2.weights[0]

# %%
m2.weights[1]

# %%
m2.weights[2]

# %%
m2.predict(t_x[:3])>0.5
# Out:
# array([[False, False, False, False, False, False, False,  True, False,
#         False],
#        [False,  True, False, False, False, False, False, False, False,
#         False],
#        [False, False, False, False, False,  True, False, False, False,
#         False]])

# %%
(x_data,y_data),(tt_x,tt_y)=keras.datasts.mnist.load_data() #필기체 인식 data
