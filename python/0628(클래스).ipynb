# %%
class 클래스명:
  def_init_(self):
    self.인스턴스변수1=0
  def setdata(입력매개변수1,....):
    self.인스턴스변수1=입력매개변수1
    ...
  def 인스턴스:
    return

# %%
class 클래스: #틀 또는 설계도 #암묵적인 룰 : 첫글자는 대문자
  pass
class 자동차: #자동차 클래스가 있다고, 자동차가 있는것은 아니다.
  pass

# %%
#class 클래스(상속받은 클래스명): #정석적인 클래스 형식
calss 클래스(object):

# %%
class 클래스: #자동차 클래스가 있다고, 자동차가 있는것은 아니다.
  pass
t=클래스() #클래스를 찍어낸것-> 객체가 만들어짐 #암묵적인 룰: 클래스는 소문자
t #main객체안에 클래스가 at 다음 주소에 만들어졌다.

# %%
class A:#클래스 만들었다
  변수=0  #클래스 안 필드 만들었다
인스턴스=A() #인스턴스가 만들어졌다.
인스턴스.변수 #인스턴스 안 변수 출력
# Out:
# 0

# %%
class A:#클래스 만들었다
  변수=0  #클래스 안 필드 만들었다
인스턴스=A() #인스턴스가 만들어졌다.
인스턴스.변수 #인스턴스 안 변수 출력
인스턴스1=A()
인스턴스1.변수=10 #인스턴스1 안 변수에 10을 넣겠다
인스턴스1.변수
# Out:
# 10

# %%
class A:#클래스 만들었다
  변수=0  #클래스 안 필드 만들었다
인스턴스=A() #인스턴스가 만들어졌다.
인스턴스.변수 #인스턴스 안 변수 출력
인스턴스1=A()
인스턴스1.변수=10 #인스턴스1 안 변수에 10을 넣겠다
인스턴스1.변수
인스턴스.변수 #인스턴스 안 변수에는 값을 넣지 않았기 때문
# Out:
# 0

# %%
class Test:
  number=0 #클래스 필드
  name=''  #클래스 필드
t1=Test() #실질적으로 없었다
t2=Test()
t1.name='소방차' #그래서 새로 만들었다. #인스턴스 필드 #그래서 서로 다른 영역이다.
t1.number=1234
t2.name='구급차'
t2.number=1004
t1,t2 #객체의 정보, 주소값이 출력됨
# Out:
# (<__main__.Test at 0x7f0aaf095790>, <__main__.Test at 0x7f0aaf0950d0>)

# %%
class 클래스명:
  def__new__(cls)
  def__init__(self):
    self.인스턴스변수1=0
  def setdata(self,입력매개변수1,...)
    self.인스턴스변수

# %% [markdown]
# 실작성코드

# %%
class Test:
  number=0
  name=''

# %% [markdown]
# 컴퓨터 스스로 변경

# %%
class Test:
  def __init__(self): #기본생성자(아무런 입력이 없는 생성자).
    pass
  number=0
  name=''

# %%
Test()

# %%
def 함수():
  pass
class Test:
  def __init__(self,x): #생성자 #반드시 self를 붙여야한다.
    pass

# %%
class Test:
  def __init__(self): #init 생성자 메소드, 클래스 안 메소드는 반드시 괄호안에 self를 입력해야함
    print('생성자 동작')
Test()
# Out:
# 생성자 동작

# %%
class Test:
  def __init__(self,x): #프로그래머가 생성자를 입력했기 때문에 기본생성자는 만들어지지않는다
    print('생성자 동작')
Test() #입력값이 없기 때문에 error 뜬다.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-afcd5dc69158> in <module>()
#       2   def __init__(self,x): #init 생성자 메소드, 클래스 안 메소드는 반드시 괄호안에 self를 입력해야함
#       3     print('생성자 동작')
# ----> 4 Test()
#
# TypeError: __init__() missing 1 required positional argument: 'x'

# %%
class Test:
  def __init__(self,x): #프로그래머가 생성자를 입력했기 때문에 기본생성자는 만들어지지않는다
    print('생성자 동작')
Test(10) # 값을 입력해주면 출력이 된다.
# Out:
# 생성자 동작

# %%
class A:
  클래스_필드='클래스_필드'
  def __init__(self): #생성자 만들기
    print("A의 생성자 동작")
  a=A()
  a.클래스_필드
# Out:
# A의 생성자 동작

# %%
class A:
  클래스_필드='클래스_필드'
  def __init__(self): #생성자 만들기
    #self 자기참조포인터 -> 인스턴스 자기자신
    print("A의 생성자 동작")
  a=A()
  a.클래스_필드
# Out:
# A의 생성자 동작

# %%
class A:
  클래스_필드='클래스_필드'
  def __init__(self): #생성자 만들기
    #self 자기참조포인터 -> 인스턴스 자기자신
    self.인스턴스_필드='인스턴스필드' #a클래스로 만들어진 인스턴스 안으로 들어간다
    print("A의 생성자 동작")
print(A.클래스_필드)
  #a=A()
  #a.클래스_필드
# Out:
# 클래스_필드

# %%
class A:
  클래스_필드='클래스_필드'
  def __init__(self): #생성자 만들기
    #self 자기참조포인터 -> 인스턴스 자기자신
    self.인스턴스_필드='인스턴스필드' #a클래스로 만들어진 인스턴스 안으로 들어간다
    print("A의 생성자 동작")
print(A.클래스_필드)
print(A.인스턴스_필드) #인스턴스 필드는 만들어지지 않았으므로(존재하지 않으므로) 접근할수가 없다 따라서 error 뜸
  #a=A()
  #a.클래스_필드
# Out:
# 클래스_필드
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-a19c56c1b645> in <module>()
#       6     print("A의 생성자 동작")
#       7 print(A.클래스_필드)
# ----> 8 print(A.인스턴스_필드) #인스턴스 필드는 만들어지지 않았으므로(존재하지 않으므로) 접근할수가 없다 따라서 error 뜸
#       9   #a=A()
#      10   #a.클래스_필드
#
# AttributeError: type object 'A' has no attribute '인스턴스_필드'

# %%
class A:
  클래스_필드='클래스_필드'
  def __init__(self): #생성자 만들기
    #self 자기참조포인터 -> 인스턴스 자기자신
    self.인스턴스_필드='인스턴스필드' #a클래스로 만들어진 인스턴스 안으로 들어간다
    print("A의 생성자 동작")
print(A.클래스_필드)
#print(A.인스턴스_필드) 
a=A()
print(a.인스턴스_필드)
# Out:
# 클래스_필드
# A의 생성자 동작
# 인스턴스필드

# %%
class 메서드:
  def __init__(self): #인스턴스 메서드
    print('메서드_생성자 동작')
  def 메서드1(self): #입력 출력 없는 메서드1
    print("메서드1 동작")
  def 메서드2(self,x): #입력 1개 출력 없는 메서드2
    print(f'{x}를 입력받는 메서드2 동작')
  def 메서드3(self):  #입력 없고 출력 1개 있는 메서드3
    return f'메서드3 동작'
  def 메서드4(slef,x,y): #입력 2개 출력 없는 메서드4
    print(f'{x},{y}를 입력받는 메서드4 동작')
  def 메서드5(self,x):#입력 1개 출력 1개 메서드5
    return f'{x}를 입력받는 메서드5 동작'
메소드5(4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-5f8c203c38d4> in <module>()
#      12   def 메서드5(self,x):#입력 1개 출력 1개 메서드5
#      13     return f'{x}를 입력받는 메서드5 동작'
# ---> 14 메소드5(4)
#
# NameError: name '메소드5' is not defined

# %%
class 메서드:
  def __init__(self): #인스턴스_메서드
    print('메서드_생성자 동작')
  def 메서드1(self): #입력 출력 없는 메서드1
    print("메서드1 동작")
  def 메서드2(self,x): #입력 1개 출력 없는 메서드2
    print(f'{x}를 입력받는 메서드2 동작')
  def 메서드3(self):  #입력 없고 출력 1개 있는 메서드3
    return f'메서드3 동작'
  def 메서드4(slef,x,y): #입력 2개 출력 없는 메서드4
    print(f'{x},{y}를 입력받는 메서드4 동작')
  def 메서드5(self,x):#입력 1개 출력 1개 메서드5
    return f'{x}를 입력받는 메서드5 동작'
메서드_인스턴스=메서드()
메서드_인스턴스.메서드1()
메서드_인스턴스.메서드2(4)
print(메서드_인스턴스.메서드3())
메서드_인스턴스.메서드4(4,5)
print(메서드_인스턴스.메서드5(4))
# Out:
# 메서드_생성자 동작
# 메서드1 동작
# 4를 입력받는 메서드2 동작
# 메서드3 동작
# 4,5를 입력받는 메서드4 동작
# 4를 입력받는 메서드5 동작

# %%
#정수형 매개변수 1개를 받고, 정수 1개를 반환하는 메소드
class A():
  def __init__(self,y):
    return f'{y}를 반환'

# %%
#클래스 -> 인스턴스멤버 == 없는 대상에 접근 하는 것
class A:
  def __init__(self):
    self.인스턴스필드='인스턴스필드'
a1=A()
a1.인스턴스필드
# Out:
# '인스턴스필드'

# %%
#클래스 -> 인스턴스멤버 == 없는 대상에 접근 하는 것
class A:
  def __init__(self):
    self.인스턴스필드='인스턴스필드'
  def 인스턴스_메서드(self):
    print('인스턴스 메서드 동작')
a1=A()
a1.인스턴스필드
a1.인스턴스_메서드()
# Out:
# 인스턴스 메서드 동작

# %%
#클래스 -> 인스턴스멤버 == 없는 대상에 접근 하는 것
class A:
  def __init__(self):
    self.인스턴스필드='인스턴스필드'
  def 인스턴스_메서드(self):
    print('인스턴스 메서드 동작')
a1=A()
a1.인스턴스필드
a1.인스턴스_메서드()
a2=A()
a2.인스턴스필드
a2.인스턴스_메서드()

# %%
class B:
  클래스_필드=10
B.클래스_필드 #클래스 만들때 만들어지므로 출력이 된다.
# Out:
# 10

# %%
class B:
  클래스_필드=10
b1=B() #기본생성자 생성
b2=B()
B.클래스_필드,b1.클래스_필드,b2.클래스_필드 #접근할수 있으므로 있는거
# Out:
# (10, 10, 10)

# %%
class B:
  클래스_필드=10
b1=B() #기본생성자 생성
b2=B()
print(B.클래스_필드,b1.클래스_필드,b2.클래스_필드) #접근할수 있으므로 있는거
B.클래스_필드=20
print(B.클래스_필드,b1.클래스_필드,b2.클래스_필드)
# Out:
# 10 10 10
# 20 20 20

# %%
class B:
  클래스_필드=10
b1=B() #기본생성자 생성
b2=B()
print(B.클래스_필드,b1.클래스_필드,b2.클래스_필드) #접근할수 있으므로 있는거
B.클래스_필드=20
print(B.클래스_필드,b1.클래스_필드,b2.클래스_필드)
b1.클래스_필드=100
print(B.클래스_필드,b1.클래스_필드,b2.클래스_필드) #없으면 만든다
# Out:
# 10 10 10
# 20 20 20
# 20 100 20

# %%
class B:
  클래스_필드=10
b1=B() #기본생성자 생성
b2=B()
print(B.클래스_필드,b1.클래스_필드,b2.클래스_필드) #접근할수 있으므로 있는거
B.클래스_필드=20
print(B.클래스_필드,b1.클래스_필드,b2.클래스_필드)
b1.클래스_필드=100
print(B.클래스_필드,b1.클래스_필드,b2.클래스_필드) #없으면 새로 만든다
B.클래스_필드=200
print(B.클래스_필드,b1.클래스_필드,b2.클래스_필드)
# Out:
# 10 10 10
# 20 20 20
# 20 100 20
# 200 100 200

# %%
a=10#변수의 선언
a=20#변수의 초기화

# %%
class C:
  @classmethod #데코레이트 선언 #보통은 인스턴스 메소드가 만들어진다. #클래스 메소드는 특수한 경우다 #따라서 데코레이트를 선언해야한다.
  def 클래스(cls):
    print("클래스_메서드_동작")
C.클래스()
# Out:
# 클래스_메서드_동작

# %%
class C:
  @classmethod #데코레이트 선언 #보통은 인스턴스 메소드가 만들어진다. #클래스 메소드는 특수한 경우다 #따라서 데코레이트를 선언해야한다.
  def 클래스(cls):
    print("클래스_메서드_동작")
C.클래스()
c1=C()
c2=C()
c1.클래스()
c2.클래스()
# Out:
# 클래스_메서드_동작
# 클래스_메서드_동작
# 클래스_메서드_동작

# %% [markdown]
# 클래스의 정리

# %%
class A:
  def __init__(self): #인스턴스 메서드
    #객체생성 시 동작하는 메서드
    print("A 생성자_동작")
#A() #객체생성,힙영역에만 만들어졋다->이름X,주소O
a=A() #이름 생성
# Out:
# A 생성자_동작

# %%
class A:
  def __init__(self): #인스턴스 메서드
    #객체생성 시 동작하는 메서드
    print("A 생성자_동작")
  def __del__(self): #소멸자 <-> 생성자 #객체 소멸시 동작하는 메서드 #이름을 날린다 -> 가비지 -> 가비지컬렉터
    pass
#A() #객체생성,힙영역에만 만들어졋다->이름X,주소O
a=A() #이름 생성
# Out:
# A 생성자_동작

# %%
class A:
  def __init__(self): #인스턴스 메서드
    #객체생성 시 동작하는 메서드
    print("A 생성자_동작")
  def 메서드(self):
#A() #객체생성,힙영역에만 만들어졋다->이름X,주소O
a=A() #이름 생성

# %%
class A:
  def __init__(self): #인스턴스 메서드
    #객체생성 시 동작하는 메서드
    print("A 생성자_동작")
  def __delattr__(self): #소멸자 <-> 생성자 #객체 소멸시 동작하는 메서드 #이름을 날린다 -> 가비지 -> 가비지컬렉터
    print("소멸")
#A() #객체생성,힙영역에만 만들어졋다->이름X,주소O
a=A() #이름 생성
# Out:
# A 생성자_동작
