# %%
from random import*
i=randint(1,100)
a=int(input())
for i in range():
  if i == a:
    print("정답입니다.")
  else:
    int(input())
  break
print(i)
# Out:
# 4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-5f6cae749d5e> in <module>()
#       2 i=randint(1,100)
#       3 a=int(input())
# ----> 4 for i in range():
#       5   if i == a:
#       6     print("정답입니다.")
#
# TypeError: range expected 1 arguments, got 0

# %%
def f():
  print('*') #출력함수 print()
  print('*')
  print('*')
  print('*')
  print('*')
f()
# Out:
# *
# *
# *
# *
# *

# %%
#함수의 기본 구조
#def 함수이름(매개변수(전달할 변수)):
#  함수의 실행 내용
def f(): #함수 생성,선언
  print("함수실행")
f() #함수 호출
f(10) # 함수 호출
# Out:
# 함수실행

# %%
#함수의 원형-모든 프로그래밍언어에서 동일한 의미
#함수가 가져야할 절대적 원칙
#하나라도 다르면 다른 함수이다.
#1.함수의 이름 - 함수 호출 규칙 때문
#2.함수의 매개변수의 수 - 기본 매개변수 디폴트 매개변수 ->자동으로 입력되는 매개변수
#3.함수의 리턴자료형 - 파이썬에서는 고민 할 필요없음-(why? 덕타이핑)
#4.함수의 매개변수 자료형 - 파이썬에서는 고민 할 필요없음-(why? 덕타이핑)
###1,2번은 함수의 호춯규칙을 결정한다.

# %%
def 함수이름(매개변수1, 매개변수2....):
  return
#int 함수이름(매개변수 1, 매개변수2.....):
  return

# %%
a=10 #a의 공간에 10객체를 넣겟다
a=20
a

# %%
def f1():
  print("함수동작")

# %%
f1()
# Out:
# 함수동작

# %%
def f1():
  print("새로운 함수")
f1()
# Out:
# 새로운 함수

# %%
def f(x):
  print(x,"입력 받은 함수")

# %%
f(10)
f('문자')
# Out:
# 10 입력 받은 함수
# 문자 입력 받은 함수

# %%
def f(x='기본값'):
  print(x,"입력 받은 함수")

# %%
f(10)
# Out:
# 10 입력 받은 함수

# %%
f()
# Out:
# 기본값 입력 받은 함수

# %%
#함수의 이름이 같으면 같은함수
#함수의 매개변수는 기본값을 가질수 있다.
#파이썬의 기본 함수 구조
'''
함수의 생성
def 함수의 이름(매개변수=기본값...):
  실행문
  return 결과값
'''

# %%
#변수의 우선순위 지역>전역
변수=10 #전역변수 -모든 영역에서 접근가능한 변수
def f():
  변수=20 #지역변수 - 특정 지역에서만 적용되는 변수,그지역을 벗어나면 존재하지 않는다.
  print(변수)
f()
print(변수)
# Out:
# 20
# 10

# %%
변수=0 #전역변수 
def f():
  print("함수 f동작")
  변수=10 #지역변수
  f1() #지역변수
  print(변수) #전역변수 호출
def f1():
  print("함수 f1동작")
  print(변수) #전역변수 호출
  #변수=20
  print(변수)
f() #함수 f호출
# Out:
# 함수 f동작
# 함수 f1동작
# 0
# 0
# 10

# %%
# ERROR 나는 경우 예시
변수=0 #전역변수 
def f():
  print("함수 f동작")
  변수=10 #지역변수
  f1() #지역변수
  print(변수) #전역변수 호출
def f1():
  print("함수 f1동작")
  print(변수) #전역변수 호출->지역변수
  변수=20 #지역변수, 함수는 선언할 때 생기고 동작은 호출하면 동작하는데, 여기서 지역변수를 선언했기때문에 한영역에 두개의 변수는 존재할 수 없다.
  print(변수) #지역변수 호출
f() #함수 f호출

# %%
변수=10 #변수의 생성
#변수=20 #변수의 초기화
def 함수(x):
  #전역변수 값 바꾸기
  변수=20 #지역변수 선언

# %%
변수=10 #변수의 생성
#변수=20 #변수의 초기화
def 함수(x):
  #전역변수 값 바꾸기
  global 변수 #global=전역 #전역변수 설정 -> 전역변수 이름 고정,지역변수 이름에 전역변수 이름 넣기
  변수=20 #전역변수 값대입

# %%
#함수는 일종의 기능
#함수 호출 후 종료시 반드시 리턴일 일어난다.
#ex
a=print('출력문')#출력함수 None
def f():
  pass
b=f()#함수의 호출로 None
a==b, a is b #None type 이뮤터블 객체 - 있으면 바꾸지 않는다
print()==f() #None이 리턴되어서 참이 된다
# Out:
# 출력문
# True

# %%
a=10
b=20
def f(a,b):
  print(a,b)
f(10,20) 
print(a,b)
# Out:
# 10 20
# 10 20

# %%
a=10
b=20
def f(a,b):
  a=20 # 지역변수 a=20 선언
  print(a,b)
f(10,20) 
print(a,b)
# Out:
# 20 20
# 10 20

# %%
a=10
b=20
def f(a=0,b=2):#함수내에서 콤마로 얘기하는 것은 각각 구분하기 위한 구분자이다.
  a=20
  print(a,b)
f(10,20)
f()#작성은 입력없이 동작하는 함수 -> 2개를 입력한 함수
print(a,b)
# Out:
# 20 20
# 20 2
# 10 20

# %%
a=10
b=20
def f(a,b=2):#디폴트 매개변수가 없으면 반드시 입력해야한다 -> 따라서 에러 뜸
  a=20
  print(a,b)
f(10,20)
f()#작성은 입력없이 동작하는 함수 -> 2개를 입력한 함수
print(a,b)
# Out:
# 20 20
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-bc536fd14435> in <module>()
#       5   print(a,b)
#       6 f(10,20)
# ----> 7 f()#작성은 입력없이 동작하는 함수 -> 2개를 입력한 함수
#       8 print(a,b)
#
# TypeError: f() missing 1 required positional argument: 'a'

# %%
a=10
b=20
def f(a,b=2):#디폴트 매개변수가 없으면 반드시 입력해야한다 -> 따라서 에러 뜸
  a=20
  print(a,b)
f(10,20)
f(10)#작성은 입력없이 동작하는 함수 -> 2개를 입력한 함수
print(a,b)
# Out:
# 20 20
# 20 2
# 10 20

# %%
a=10
b=20
def f(a,b=2,c):#특수 매개변수를 사용하면 절대 다음에는 일반매개변수가 올수 없다. 따라서 특수 매개 변수를 사용하려면 제일 뒷자리에 사용해야한다.
  a=20
  print(a,b)
f(10,20)
f(10)#작성은 입력없이 동작하는 함수 -> 2개를 입력한 함수
print(a,b)

# %%
a=10
b=20
def f(a,b=2,c=2):#특수 매개변수를 사용하면 절대 다음에는 일반매개변수가 올수 없다. 따라서 특수 매개 변수를 사용하려면 제일 뒷자리에 사용해야한다.
  a=20
  print(a,b)
f(10,20)
f(10)#작성은 입력없이 동작하는 함수 -> 2개를 입력한 함수
print(a,b)
# Out:
# 20 20
# 20 2
# 10 20

# %%
a=10
b=20
def f(a,b=2,c=2):#특수 매개변수를 사용하면 절대 다음에는 일반매개변수가 올수 없다. 따라서 특수 매개 변수를 사용하려면 제일 뒷자리에 사용해야한다.
  print(a,b,c)
#f(10,20)
#f(10)#작성은 입력없이 동작하는 함수 -> 2개를 입력한 함수
#print(a,b)
f(10,20,30)
f(c=10,b=20,a=30)
print(end=',',sep='')
# Out:
# 10 20 30
# 30 20 10
# ,

# %%
전역변수='전역변수'
def 함수(입력): 
  #실행문
  print(전역변수)
함수(10)
# Out:
# 전역변수

# %%
전역변수='전역변수'
def 함수(입력): 
  #실행문
  print(전역변수)
  전역변수=10 #수정은 불가능하다!!!
함수(10)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-17-4cdaaf2dc138> in <module>()
#       4   print(전역변수)
#       5   전역변수=10
# ----> 6 함수(10)
#
# <ipython-input-17-4cdaaf2dc138> in 함수(입력)
#       2 def 함수(입력):
#       3   #실행문
# ----> 4   print(전역변수)
#       5   전역변수=10
#       6 함수(10)
#
# UnboundLocalError: local variable '전역변수' referenced before assignment

# %%
전역변수='전역변수'
def 함수(입력):
  global 전역변수 #전역변수를 수정하기 위해 접근경로인 global 사용 ,같은 이름의 지역변수를 선언한 것과 동급이다.
  #실행문
  #print(전역변수)
  전역변수=10 
함수(10)

# %%
def 양수_음수_판별함수(x):
  if x>=0:
    return
    for i in range(시작,종료+1):
      out_data+=1
    if out_data%2==0:
      return f'{out_data}는 짝수'
    else:
      return f'{out_data}는 홀수'

# %%
def f():
  pass
def f(x):
  pass
#같은 이름의 다른 함수를 호출, 함수 오버로딩, 파이썬은 함수 오버로딩이 없다!!!!(Because 디폴트 매개변수)
f()
f(10)

# %%
def f(x):
  pass
f(10)

# %%
#같은 함수 호출
def f(x=10): #기본매개변수는 입력이 없을때 자동으로 들어가는 매개변수
  pass
f(10) #겉모습 -> 이름(입력값 1개) -> 실동작 : 이름(입력값1개)
f()   #겉모습 -> 이름(입력값 0개) -> 실동작 : 이름(입력값1개)

# %%
id(f) #함수도 객체다
a=f

# %%
#같은 함수 호출
def f(x=10): #기본매개변수는 입력이 없을때 자동으로 들어가는 매개변수
  print("함수동작")
f(10) #겉모습 -> 이름(입력값 1개) -> 실동작 : 이름(입력값1개)
f()   #겉모습 -> 이름(입력값 0개) -> 실동작 : 이름(입력값1개)
# Out:
# 함수동작
# 함수동작

# %%
a=f #함수도 객체이므로 이름을 변경 할 수도 있다.

# %%
a(10)
# Out:
# 함수동작

# %%
def f1(x=10): #기본매개변수는 입력이 없을때 자동으로 들어가는 매개변수
  print("1번 함수동작")
def f2(x=10): #기본매개변수는 입력이 없을때 자동으로 들어가는 매개변수
  print("2번 함수동작")

# %%
a=[f1, f2]

# %%
a[1](10)
# Out:
# 2번 함수동작

# %%
def f():
  return 1,2,3,4 #return=값의 전달, 함수의 종료 break와 비슷하다.
f()
# Out:
# (1, 2, 3, 4)

# %%
def f(x):
  if x==0:
    return 0 #동시에 여러개의 return이 동작할수 없다
  return     #하나의 동작에 하나의 결과를 만들어낸다. 헷갈리면 연산 생각하자, 하나의 연산자로 하나의 결과값만 도출해낸다.
print(f(1))
# Out:
# None
