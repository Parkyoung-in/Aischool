# %%
from random import randint
x=randint(1,100)
i=0
l=[]
while True:
  n=int(input("정답을 입력하시오 : "))
  l.append(n)
  i+=1
  if n>x:
    print("Down")
  elif n<x:
    print("Up")
  else:
    print(f'{i}회째 정답!')
    break
print(l)
# Out:
# 정답을 입력하시오 : 50
# Down
# 정답을 입력하시오 : 30
# Down
# 정답을 입력하시오 : 20
# Down
# 정답을 입력하시오 : 10
# Down
# 정답을 입력하시오 : 5
# Up
# 정답을 입력하시오 : 7
# Down
# 정답을 입력하시오 : 6
# 7회째 정답!
# [50, 30, 20, 10, 5, 7, 6]
